# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy() 
#Let's plot the Timeseries
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor="#627D78")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %%
#Pivoting data fron junction 
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415548
# p-value: 4.798539876395171e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940133
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832824
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.979092563052266
# p-value: 2.7787875325955e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0799WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 42s 308ms/step - loss: 0.0799
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0662WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 317ms/step - loss: 0.0662
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 317ms/step - loss: 0.0647
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0629WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 302ms/step - loss: 0.0629
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0611WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 319ms/step - loss: 0.0611
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0603WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 321ms/step - loss: 0.0603
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0597WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 321ms/step - loss: 0.0597
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0590WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 314ms/step - loss: 0.0590
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0582WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 288ms/step - loss: 0.0582
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0574WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 300ms/step - loss: 0.0574
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0566WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 302ms/step - loss: 0.0566
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 297ms/step - loss: 0.0561
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0553WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 300ms/step - loss: 0.0553
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0548WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 287ms/step - loss: 0.0548
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0543WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 296ms/step - loss: 0.0543
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 285ms/step - loss: 0.0537
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0536WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 305ms/step - loss: 0.0536
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 59s 686ms/step - loss: 0.0530
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0527WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 305ms/step - loss: 0.0527
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0518WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 288ms/step - loss: 0.0518
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 284ms/step - loss: 0.0515
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 289ms/step - loss: 0.0513
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0510WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 294ms/step - loss: 0.0510
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 316ms/step - loss: 0.0514
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 306ms/step - loss: 0.0513
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0510WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 311ms/step - loss: 0.0510
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0506WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 295ms/step - loss: 0.0506
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0506WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 305ms/step - loss: 0.0506
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 320ms/step - loss: 0.0497
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0501WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0501
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 327ms/step - loss: 0.0499
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 320ms/step - loss: 0.0503
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 291ms/step - loss: 0.0497
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 287ms/step - loss: 0.0492
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 289ms/step - loss: 0.0493
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 283ms/step - loss: 0.0492
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 288ms/step - loss: 0.0491
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 281ms/step - loss: 0.0495
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 321ms/step - loss: 0.0493
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 350ms/step - loss: 0.0486
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0490WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 295ms/step - loss: 0.0490
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 288ms/step - loss: 0.0484
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 293ms/step - loss: 0.0488
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 287ms/step - loss: 0.0487
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 295ms/step - loss: 0.0487
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 291ms/step - loss: 0.0480
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 290ms/step - loss: 0.0482
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0476WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 296ms/step - loss: 0.0476
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 282ms/step - loss: 0.0488
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 313ms/step - loss: 0.0479
# 45/45 [==============================] - 7s 40ms/step

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.2476789461072223.

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2271WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 52s 294ms/step - loss: 0.2271
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2030WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 288ms/step - loss: 0.2030
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1995WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1995
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.1950
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1922WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.1922
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.1918
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1914
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1910WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 287ms/step - loss: 0.1910
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 310ms/step - loss: 0.1897
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1865
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1886
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 313ms/step - loss: 0.1888
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 279ms/step - loss: 0.1863
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 286ms/step - loss: 0.1857
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 281ms/step - loss: 0.1866
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1855WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.1855
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1873WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.1873
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1855WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 285ms/step - loss: 0.1855
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1851WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 287ms/step - loss: 0.1851
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 317ms/step - loss: 0.1862
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.1860
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1859
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 295ms/step - loss: 0.1838
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 289ms/step - loss: 0.1841
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1853WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 295ms/step - loss: 0.1853
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 305ms/step - loss: 0.1849
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 297ms/step - loss: 0.1850
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1842WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 285ms/step - loss: 0.1842
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.1838
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 304ms/step - loss: 0.1835
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 303ms/step - loss: 0.1838
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 290ms/step - loss: 0.1832
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 304ms/step - loss: 0.1827
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.1832
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 297ms/step - loss: 0.1834
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 289ms/step - loss: 0.1834
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 300ms/step - loss: 0.1834
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1831
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.1810
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1814
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 309ms/step - loss: 0.1836
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.1816
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.1813
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1815WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 288ms/step - loss: 0.1815
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1842WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1842
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 289ms/step - loss: 0.1812
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 319ms/step - loss: 0.1812
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1796WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 281ms/step - loss: 0.1796
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 280ms/step - loss: 0.1814
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 281ms/step - loss: 0.1816
# 45/45 [==============================] - 7s 38ms/step

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5520174783914084.

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3032WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 52s 289ms/step - loss: 0.3032
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 305ms/step - loss: 0.2950
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 290ms/step - loss: 0.2899
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 305ms/step - loss: 0.2933
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2881WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 296ms/step - loss: 0.2881
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2927WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 290ms/step - loss: 0.2927
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 290ms/step - loss: 0.2894
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 326ms/step - loss: 0.2886
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2920WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 297ms/step - loss: 0.2920
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2867WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 302ms/step - loss: 0.2867
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 304ms/step - loss: 0.2868
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2854WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 296ms/step - loss: 0.2854
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.2850
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 321ms/step - loss: 0.2834
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 295ms/step - loss: 0.2831
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2799WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 303ms/step - loss: 0.2799
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 300ms/step - loss: 0.2817
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2804WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 317ms/step - loss: 0.2804
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2768WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 295ms/step - loss: 0.2768
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2742WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 310ms/step - loss: 0.2742
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2751WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.2751
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2757WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 295ms/step - loss: 0.2757
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2749WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 307ms/step - loss: 0.2749
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2741WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 309ms/step - loss: 0.2741
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2724WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 304ms/step - loss: 0.2724
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2739WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.2739
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2739WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.2739
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2701WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 326ms/step - loss: 0.2701
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2723WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 304ms/step - loss: 0.2723
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2722WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 297ms/step - loss: 0.2722
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2693WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 307ms/step - loss: 0.2693
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2712WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 306ms/step - loss: 0.2712
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2674WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 304ms/step - loss: 0.2674
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2700WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 295ms/step - loss: 0.2700
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2695WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 303ms/step - loss: 0.2695
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2686WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.2686
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 324ms/step - loss: 0.2692
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2673WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 306ms/step - loss: 0.2673
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2690 WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 2036s 23s/step - loss: 0.2690
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 266ms/step - loss: 0.2688
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.2664
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2665WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 259ms/step - loss: 0.2665
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 265ms/step - loss: 0.2650
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2657WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 280ms/step - loss: 0.2657
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2654WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 296ms/step - loss: 0.2654
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2680WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 283ms/step - loss: 0.2680
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2653WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.2653
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 286ms/step - loss: 0.2647
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2630WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 317ms/step - loss: 0.2630
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2626WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.2626
# 45/45 [==============================] - 7s 40ms/step

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6081113653329333.

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 32s 297ms/step - loss: 0.6933
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6975WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6975
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6853WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 295ms/step - loss: 0.6853
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6861WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 287ms/step - loss: 0.6861
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6891WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 286ms/step - loss: 0.6891
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6839
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 288ms/step - loss: 0.6811
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6798WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 290ms/step - loss: 0.6798
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 287ms/step - loss: 0.6813
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 344ms/step - loss: 0.6821
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6805WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 282ms/step - loss: 0.6805
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 304ms/step - loss: 0.6795
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 279ms/step - loss: 0.6828
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 306ms/step - loss: 0.6795
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6788WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 280ms/step - loss: 0.6788
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6758WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 303ms/step - loss: 0.6758
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6779WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 283ms/step - loss: 0.6779
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6759
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6792WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 320ms/step - loss: 0.6792
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6775WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 287ms/step - loss: 0.6775
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6774WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 310ms/step - loss: 0.6774
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6755WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 280ms/step - loss: 0.6755
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6761WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 408ms/step - loss: 0.6761
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6702WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 312ms/step - loss: 0.6702
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 285ms/step - loss: 0.6692
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6717WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 303ms/step - loss: 0.6717
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6687WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 288ms/step - loss: 0.6687
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6655WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 292ms/step - loss: 0.6655
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6660WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 307ms/step - loss: 0.6660
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 290ms/step - loss: 0.6658
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 313ms/step - loss: 0.6650
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6704WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 283ms/step - loss: 0.6704
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 316ms/step - loss: 0.6650
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6545WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 292ms/step - loss: 0.6545
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6561
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 316ms/step - loss: 0.6488
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6396WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 302ms/step - loss: 0.6396
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6403WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 377ms/step - loss: 0.6403
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6277WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6277
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6208WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 286ms/step - loss: 0.6208
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 313ms/step - loss: 0.6375
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6269WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 289ms/step - loss: 0.6269
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6048WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 321ms/step - loss: 0.6048
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6193WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 293ms/step - loss: 0.6193
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5855WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 307ms/step - loss: 0.5855
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5712WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 347ms/step - loss: 0.5712
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 359ms/step - loss: 0.5642
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5629WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 279ms/step - loss: 0.5629
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 292ms/step - loss: 0.5561
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5395WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 278ms/step - loss: 0.5395
# 13/13 [==============================] - 6s 38ms/step

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 0.9994315742095373.

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True,facecolor="#627D78")
    fig.suptitle(title)
    
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")
    
    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Orignal")

# %%
# invert the differenced forecast for Junction 1 
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Pridictions And Orignals For Junction 1", 0)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Pridictions And Orignals For Junction 2", 1)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Pridictions And Orignals For Junction 3", 2)

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Pridictions And Orignals For Junction 4", 3)
